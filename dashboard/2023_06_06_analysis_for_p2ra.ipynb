# %%
import pandas as pd

# Prints output of all commands in a cell, not only the final command.
from IPython.core.interactiveshell import InteractiveShell

InteractiveShell.ast_node_interactivity = "all"

# Import metadata_target_samples.tsv into a pandas dataframe

metadata_target_samples = pd.read_csv("metadata_target_samples.tsv", sep="\t")

# Print the smallest and largest date for all samples with location = Los Angeles

# metadata_target_samples[metadata_target_samples["location"] == "Los Angeles"].sort_values(by="date")

metadata_target_samples[
    metadata_target_samples["location"] == "San Francisco"
].sort_values(by="date")
# Out:
#        accession        country                county enrichment
# 8    SRR12596173  United States        Alameda County      panel  \
# 2    SRR12596167  United States        Alameda County      panel
# 7    SRR12596172  United States        Alameda County      panel
# 5    SRR12596170  United States        Alameda County      panel
# 1    SRR12596166  United States        Alameda County      panel
# 4    SRR12596169  United States        Alameda County      panel
# 0    SRR12596165  United States        Alameda County      panel
# 3    SRR12596168  United States        Alameda County      panel
# 434  SRR23998358  United States        Alameda County      viral
# 9    SRR12596174  United States        Alameda County      panel
# 429  SRR23998353  United States        Alameda County      viral
# 432  SRR23998356  United States  San Francisco County      viral
# 433  SRR23998357  United States        Alameda County      viral
# ...

# %%
metadata_target_samples[
    metadata_target_samples["location"] == "San Francisco"
].sort_values(by="date")


# Listing methods used by samples with location = San Francisco and enrichment = viral


metadata_target_samples[(metadata_target_samples["location"] == "San Francisco")][
    "method"
].value_counts()

metadata_target_samples[
    (metadata_target_samples["location"] == "San Francisco")
    & (metadata_target_samples["enrichment"] == "viral")
]["method"].value_counts()
# Out:
#        accession        country                county enrichment
# 8    SRR12596173  United States        Alameda County      panel  \
# 2    SRR12596167  United States        Alameda County      panel
# 7    SRR12596172  United States        Alameda County      panel
# 5    SRR12596170  United States        Alameda County      panel
# 1    SRR12596166  United States        Alameda County      panel
# 4    SRR12596169  United States        Alameda County      panel
# 0    SRR12596165  United States        Alameda County      panel
# 3    SRR12596168  United States        Alameda County      panel
# 434  SRR23998358  United States        Alameda County      viral
# 9    SRR12596174  United States        Alameda County      panel
# 429  SRR23998353  United States        Alameda County      viral
# 432  SRR23998356  United States  San Francisco County      viral
# 433  SRR23998357  United States        Alameda County      viral
# ...
